# %%
df_silver = spark.read.format("delta") \
    .load("/Volumes/loan/credit_score/prediction/silver")

display(df_silver)

# %%
# %sql
CREATE OR REPLACE TABLE loan.credit_score.loan_high_risk_customers AS
SELECT *
FROM loan.credit_score.silver
WHERE loan_default = 1;

# %%
# %sql
CREATE OR REPLACE TABLE loan_portfolio_risk AS
SELECT
  interest_bucket,
  COUNT(*) AS total_loans
FROM loan.credit_score.silver
GROUP BY interest_bucket;

# %%
# %sql
CREATE OR REPLACE TABLE loan_mom_delinquency AS
SELECT
  year(try_cast(issue_d AS DATE)) as year,
  MONTH(try_cast(issue_d AS DATE)) AS month,
  AVG(loan_default) AS delinquency_rate
FROM loan.credit_score.silver
GROUP BY year(try_cast(issue_d As Date)),MONTH(try_cast(issue_d AS DATE))
ORDER BY year,month;

# %%
# %sql
SELECT
  id,
  loan_amnt,
  int_rate,
  interest_bucket
  loan_default,
  dti,
  loan_status
FROM loan_high_risk_customers;
# Out:
# Databricks visualization. Run in Databricks to view.

# %%
# %sql
SELECT
  interest_bucket,
  total_loans
FROM loan_portfolio_risk;
# Out:
# Databricks visualization. Run in Databricks to view.

# %%
# %sql
SELECT
  year,month,
  delinquency_rate
FROM loan_mom_delinquency;
