# %%
dbutils.fs.ls("/Volumes/loan/credit_score/prediction")

# %%
df_bronze = (
    spark.read
    .option("header", "true")
    .option("inferSchema", "true")
    .csv("/Volumes/loan/credit_score/prediction/loan_datasets.csv")
)

# %%
display(df_bronze)

# %%
df_bronze.printSchema()

# %%
df_bronze.write \
    .format("delta") \
    .option("mergeSchema", "true") \
    .mode("overwrite") \
    .save("/Volumes/loan/credit_score/prediction/bronze")

# %%
spark.read.format("delta") \
    .load("/Volumes/loan/credit_score/prediction/bronze") \
    .display()
